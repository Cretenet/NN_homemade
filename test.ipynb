# %%
from neural_network import NeuralNetwork
import numpy as np

# %%
NN = NeuralNetwork(3, "input layer")
np.random.seed(0)
NN.add_hidden_layer("first hidden layer", 2, "RELU")
NN.add_output_layer("output layer", 1, "sigmoid")
NN.weights[1] = np.array([[1, 2, 3], [4, 5, 6]])
print(NN.weights[2])
print(NN.weights[1])
# Out:
# [[ 0.31669614 -0.0504524 ]]
# [[1 2 3]
#  [4 5 6]]

# %%
from activation_functions import sigmoid
sigmoid(0.249)
# Out:
# 0.5619303515188666

# %%
X = np.random.rand(256, 3)
print(X.ndim)
# Out:
# 2

# %%
from neural_network import NeuralNetwork
import numpy as np

# %%
np.random.seed(0)
epsilon = 1e-5
NN = NeuralNetwork(input_size=256, input_layer_name="input")
NN.add_hidden_layer(nb_neurons=128, activation="RELU")
NN.add_hidden_layer(nb_neurons=64, activation="RELU")
NN.add_output_layer(nb_outputs=1, activation="softmax", cost="MSE")
X = np.random.rand(256, 100)
Y = np.random.rand(1, 100)
V1 = NN.forward_propagation(X)
cost = NN.evaluate(V1, Y)
NN.backward_propagation(Y)
print(NN.dW[3])
# Out:
# [[0.50004532 0.50003688 0.50003332 0.50001496 0.50003295 0.50003338
#   0.50002895 0.500027   0.50003205 0.5000414  0.5000346  0.50002076
#   0.5000496  0.50001703 0.50002906 0.50003783 0.50004032 0.50003975
#   0.50003505 0.50003562 0.50003945 0.50003527 0.50003047 0.50003572
#   0.50002577 0.50004891 0.50002819 0.50004094 0.50004504 0.50002952
#   0.5000442  0.50004356 0.50002483 0.50004671 0.5000486  0.50003252
#   0.50002498 0.50003405 0.50003178 0.50003584 0.50003303 0.5000318
#   0.50003597 0.50003304 0.50002692 0.5000451  0.50005215 0.50001856
#   0.50002407 0.50002718 0.50002593 0.50002863 0.50003545 0.50004484
#   0.50002016 0.50003683 0.50005089 0.500023   0.50001592 0.50002443
#   0.5000477  0.50003176 0.50003435 0.50004066 0.50002605 0.50003345
#   0.50003143 0.50001796 0.50002415 0.50002339 0.50001501 0.50001838
#   0.50004077 0.50003748 0.50002603 0.50002107 0.50003288 0.50002288
#   0.50002089 0.5000328  0.50001967 0.50003888 0.50001013 0.50004698
# ...

# %%
import numpy as np
1/(1+np.exp(-0.518204673900277))
# Out:
# 0.6267278632862692
